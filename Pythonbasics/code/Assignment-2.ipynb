# %%
students_info = {
    "Aarav": {"age": 20, "major": "Computer Science", "gpa": 3.8},
    "Bhavya": {"age": 22, "major": "Mathematics", "gpa": 3.4},
    "Chirag": {"age": 19, "major": "Physics", "gpa": 3.9},
    "Divya": {"age": 21, "major": "Biology", "gpa": 3.7},
    "Esha": {"age": 23, "major": "Chemistry", "gpa": 3.5}
}

# %%
print(students_info["Aarav"]["major"])
# What is Aarav's major? Write the Python code to get it.
# Out:
# Computer Science

# %%
print(students_info["Chirag"]["age"])
# . How old is Chirag? Write the Python code to find his age.
# Out:
# 19

# %%
print(students_info["Bhavya"]["gpa"])
# Get Bhavya's GPA using Python.
# Out:
# 3.4

# %%
students_info["Farhan"] = {
    "age": 24,
    "major": "Engineering",
    "gpa": 3.6
}
# Add a new student "Farhan" with age 24, major "Engineering", and GPA 3.6

# %%
print(students_info)
# Out:
# {'Aarav': {'age': 20, 'major': 'Computer Science', 'gpa': 3.8}, 'Bhavya': {'age': 22, 'major': 'Mathematics', 'gpa': 3.4}, 'Chirag': {'age': 19, 'major': 'Physics', 'gpa': 3.9}, 'Divya': {'age': 21, 'major': 'Biology', 'gpa': 3.9}, 'Esha': {'age': 23, 'major': 'Chemistry', 'gpa': 3.5}, 'Farhan': {'age': 24, 'major': 'Engineering', 'gpa': 3.6}}

# %%
students_info["Divya"]["gpa"]=3.9
print(students_info)
# Update Divya's GPA to 3.9.
# Out:
# {'Aarav': {'age': 20, 'major': 'Computer Science', 'gpa': 3.8}, 'Bhavya': {'age': 22, 'major': 'Mathematics', 'gpa': 3.4}, 'Chirag': {'age': 19, 'major': 'Physics', 'gpa': 3.9}, 'Divya': {'age': 21, 'major': 'Biology', 'gpa': 3.9}, 'Esha': {'age': 23, 'major': 'Chemistry', 'gpa': 3.5}, 'Farhan': {'age': 24, 'major': 'Engineering', 'gpa': 3.6}}

# %%
for name in students_info:
    print(name)
#  Write Python code to list all the student names.
# Out:
# Aarav
# Bhavya
# Chirag
# Divya
# Esha
# Farhan

# %%
average_gpa = sum(student["gpa"] for student in students_info.values()) / len(students_info)
print("Average GPA:", average_gpa)

#Write Python code to find the average GPA of all students.
# Out:
# Average GPA: 3.6833333333333336

# %%
del students_info["Esha"]
print(students_info)
# Remove Esha from the dictionary.
# Out:
# {'Aarav': {'age': 20, 'major': 'Computer Science', 'gpa': 3.8}, 'Bhavya': {'age': 22, 'major': 'Mathematics', 'gpa': 3.4}, 'Chirag': {'age': 19, 'major': 'Physics', 'gpa': 3.9}, 'Divya': {'age': 21, 'major': 'Biology', 'gpa': 3.9}, 'Farhan': {'age': 24, 'major': 'Engineering', 'gpa': 3.6}}

# %%
#Check if "Gaurav" is in the dictionary.
if "Gaurav" in students_info:
    print("Exists")
else:
    print('Not exists')
# Out:
# Not exists
